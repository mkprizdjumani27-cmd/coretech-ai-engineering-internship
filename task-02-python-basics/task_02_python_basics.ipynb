# %%
name = "Muhammad"
age = 19
city = "Hyderabad"

print(name)
print(age)
print(city)
# Out:
# Muhammad
# 19
# Hyderabad

# %%
company = "CoreTech"
employees = 50
rating = 4.8
is_active = True

print(company)
print(employees)
print(rating)
print(is_active)
# Out:
# CoreTech
# 50
# 4.8
# True

# %%
services = ["AI Chatbot", "Web Development", "Data Analysis"]

print(services)
# Out:
# ['AI Chatbot', 'Web Development', 'Data Analysis']

# %%
services = ["AI Chatbot", "Web Development", "Data Analysis"]

for service in services:
    print(service)
# Out:
# AI Chatbot
# Web Development
# Data Analysis

# %%
client = {
    "name": "Ali",
    "service": "AI Chatbot",
    "budget": 50000
}

print(client)
# Out:
# {'name': 'Ali', 'service': 'AI Chatbot', 'budget': 50000}

# %%
client_inquiry = {
    "client_name": "Ahmed",
    "business_type": "E-commerce",
    "required_service": "AI Chatbot",
    "budget": 100000
}

print(client_inquiry)
# Out:
# {'client_name': 'Ahmed', 'business_type': 'E-commerce', 'required_service': 'AI Chatbot', 'budget': 100000}

# %%
def recommend_service(business_type):

    if business_type == "E-commerce":
        return "AI Chatbot"

    elif business_type == "Education":
        return "LMS System"

    else:
        return "Web Development"


result = recommend_service("E-commerce")

print(result)
# Out:
# AI Chatbot

# %%
print("Welcome to CoreTech Assistant")

name = input("Enter your name: ")

business = input("Enter your business type: ")

print("Hello", name)

if business == "E-commerce":
    print("Recommended Service: AI Chatbot")

elif business == "Education":
    print("Recommended Service: LMS System")

else:
    print("Recommended Service: Web Development")
# Out:
# Welcome to CoreTech Assistant
# Enter your name: Muhammad
# Enter your business type: E-commerce
# Hello Muhammad
# Recommended Service: AI Chatbot
